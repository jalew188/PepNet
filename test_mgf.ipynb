# %%
import warnings
warnings.filterwarnings("ignore")
from denovo import read_mgf_spectra, load_model, predict_spectra

model = load_model("model.h5")
# Out:
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# ...

# %%
spectra = read_mgf_spectra("validation.mgf")
df = predict_spectra(model, spectra)
df
# Out:
# Loading validation.mgf ...
# 1/1 [==============================] - 64s 64s/step
#     raw_name  spec_idx                    sequence  \
# 0                   -1  AAAAAAAAAAAAAAASGFAYPGTSER
# 1                   -1               AAALSLSTLASPK
# 2                   -1               AADLHTFSSVLEK
# 3                   -1                  AAEPLLTLER
# 4                   -1                AAGLQAELGQVK
# ..       ...       ...                         ...
# 108                 -1                DDDRYEQASDVR
# 109                 -1                   DDPTTGAWR
# 110                 -1                  DEDENVNLYR
# 111                 -1            DELELDFETLKPSTLR
# 112                 -1               DERYFFQGNQYWR
#
#              predicted_sequence     score  \
# 0    AAAAAAAAAAAAAAASSFFGPGTSER  0.092981
# 1                 AAALSLSTLASPK  0.999285
# 2                 AADLHTFSSVLEK  0.999605
# 3                    AAEPLLTLER  0.999567
# 4                  AAGLQAELGQVK  0.999857
# ...
